# %%
import inventory as ivp
from IPython.display import display

inventory = ivp.Inventory()
# Out:
# ...
#   creator component_name concentration component_id is_buffer  \
# 0    qwer          qwerq          werq   qwerq_werq       wer
#
#              curr_time
# 0  2023/06/22 01:21:56
#   creator component_name concentration component_id is_buffer  \
# 0    qwer          qwerq          werq   qwerq_werq       wer
#
#              curr_time
# 0  2023/06/22 01:21:56
